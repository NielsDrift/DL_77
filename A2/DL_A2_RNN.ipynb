# %% [markdown]
# <div style="text-align: right">   </div>
#
#
# Introduction to Deep Learning (2023) &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;| &nbsp;
# -------|-------------------
# **Assignment 2 - Recurrent Neural Networks** | <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/UniversiteitLeidenLogo.svg/1280px-UniversiteitLeidenLogo.svg.png" width="300">
#
#
#
# # Introduction
#
#
# The goal of this assignment is to learn how to use encoder-decoder recurrent neural networks (RNNs). Specifically we will be dealing with a sequence to sequence problem and try to build recurrent models that can learn the principles behind simple arithmetic operations (**integer addition, subtraction and multiplication.**).
#
# <img src="https://i.ibb.co/5Ky5pbk/Screenshot-2023-11-10-at-07-51-21.png" alt="Screenshot-2023-11-10-at-07-51-21" border="0" width="500"></a>
#
# In this assignment you will be working with three different kinds of models, based on input/output data modalities:
# 1. **Text-to-text**: given a text query containing two integers and an operand between them (+ or -) the model's output should be a sequence of integers that match the actual arithmetic result of this operation
# 2. **Image-to-text**: same as above, except the query is specified as a sequence of images containing individual digits and an operand.
# 3. **Text-to-image**: the query is specified in text format as in the text-to-text model, however the model's output should be a sequence of images corresponding to the correct result.
#
#
# ### Description**
# Let us suppose that we want to develop a neural network that learns how to add or subtract
# two integers that are at most two digits long. For example, given input strings of 5 characters: ‘81+24’ or
# ’41-89’ that consist of 2 two-digit long integers and an operand between them, the network should return a
# sequence of 3 characters: ‘105 ’ or ’-48 ’ that represent the result of their respective queries. Additionally,
# we want to build a model that generalizes well - if the network can extract the underlying principles behind
# the ’+’ and ’-’ operands and associated operations, it should not need too many training examples to generate
# valid answers to unseen queries. To represent such queries we need 13 unique characters: 10 for digits (0-9),
# 2 for the ’+’ and ’-’ operands and one for whitespaces ’ ’ used as padding.
# The example above describes a text-to-text sequence mapping scenario. However, we can also use different
# modalities of data to represent our queries or answers. For that purpose, the MNIST handwritten digit
# dataset is going to be used again, however in a slightly different format. The functions below will be used to create our datasets.
#
# ---
#
# *To work on this notebook you should create a copy of it.*

# %% [markdown]
# # Function definitions for creating the datasets
#
# First we need to create our datasets that are going to be used for training our models.
#
# In order to create image queries of simple arithmetic operations such as '15+13' or '42-10' we need to create images of '+' and '-' signs using ***open-cv*** library. We will use these operand signs together with the MNIST dataset to represent the digits.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import numpy as np
import tensorflow as tf
import random
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Dense, RNN, LSTM, Flatten, TimeDistributed, LSTMCell, Input
from tensorflow.keras.layers import RepeatVector, Conv2D, SimpleRNN, GRU, Reshape, ConvLSTM2D, Conv2DTranspose, MaxPooling2D
from tensorflow.keras.models import Model
from keras.layers import Input, Dense, LSTM, Embedding, Conv2D, MaxPooling2D, Flatten, Reshape, TimeDistributed, Bidirectional, Concatenate, Attention, Dropout

from keras.optimizers import RMSprop

# %%
from scipy.ndimage import rotate
# Create plus/minus operand signs
def generate_images(number_of_images=50, sign='-'):

    blank_images = np.zeros([number_of_images, 28, 28])  # Dimensionality matches the size of MNIST images (28x28)
    x = np.random.randint(12, 16, (number_of_images, 2)) # Randomized x coordinates
    y1 = np.random.randint(6, 10, number_of_images)       # Randomized y coordinates
    y2 = np.random.randint(18, 22, number_of_images)     # -||-

    for i in range(number_of_images): # Generate n different images
        cv2.line(blank_images[i], (y1[i], x[i,0]), (y2[i], x[i, 1]), (255,0,0), 2, cv2.LINE_AA)     # Draw lines with randomized coordinates
        if sign == '+':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA) # Draw lines with randomized coordinates
        if sign == '*':
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            # Rotate 45 degrees
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)
            blank_images[i] = rotate(blank_images[i], -50, reshape=False)
            cv2.line(blank_images[i], (x[i,0], y1[i]), (x[i, 1], y2[i]), (255,0,0), 2, cv2.LINE_AA)

    return blank_images

def show_generated(images, n=5):
    plt.figure(figsize=(2, 2))
    for i in range(n**2):
        plt.subplot(n, n, i+1)
        plt.axis('off')
        plt.imshow(images[i])
    plt.show()

show_generated(generate_images())
show_generated(generate_images(sign='+'))

# %%
def create_data(highest_integer, num_addends=2, operands=['+', '-']):
    """
    Creates the following data for all pairs of integers up to [1:highest integer][+/-][1:highest_integer]:

    @return:
    X_text: '51+21' -> text query of an arithmetic operation (5)
    X_img : Stack of MNIST images corresponding to the query (5 x 28 x 28) -> sequence of 5 images of size 28x28
    y_text: '72' -> answer of the arithmetic text query
    y_img :  Stack of MNIST images corresponding to the answer (3 x 28 x 28)

    Images for digits are picked randomly from the whole MNIST dataset.
    """

    num_indices = [np.where(MNIST_labels==x) for x in range(10)]
    num_data = [MNIST_data[inds] for inds in num_indices]
    image_mapping = dict(zip(unique_characters[:10], num_data))
    image_mapping['-'] = generate_images()
    image_mapping['+'] = generate_images(sign='+')
    image_mapping['*'] = generate_images(sign='*')
    image_mapping[' '] = np.zeros([1, 28, 28])

    X_text, X_img, y_text, y_img = [], [], [], []

    for i in range(highest_integer + 1):      # First addend
        for j in range(highest_integer + 1):  # Second addend
            for sign in operands: # Create all possible combinations of operands
                query_string = to_padded_chars(str(i) + sign + str(j), max_len=max_query_length, pad_right=True)
                query_image = []
                for n, char in enumerate(query_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    query_image.append(image_set[index].squeeze())

                result = eval(query_string)
                result_string = to_padded_chars(result, max_len=max_answer_length, pad_right=True)
                result_image = []
                for n, char in enumerate(result_string):
                    image_set = image_mapping[char]
                    index = np.random.randint(0, len(image_set), 1)
                    result_image.append(image_set[index].squeeze())

                X_text.append(query_string)
                X_img.append(np.stack(query_image))
                y_text.append(result_string)
                y_img.append(np.stack(result_image))

    return np.stack(X_text), np.stack(X_img)/255., np.stack(y_text), np.stack(y_img)/255.

def to_padded_chars(integer, max_len=3, pad_right=False):
    """
    Returns a string of len()=max_len, containing the integer padded with ' ' on either right or left side
    """
    length = len(str(integer))
    padding = (max_len - length) * ' '
    if pad_right:
        return str(integer) + padding
    else:
        return padding + str(integer)

# %% [markdown]
# # Creating our data
#
# The dataset consists of 20000 samples that (additions and subtractions between all 2-digit integers) and they have two kinds of inputs and label modalities:
#
#   **X_text**: strings containing queries of length 5: ['  1+1  ', '11-18', ...]
#
#   **X_image**: a stack of images representing a single query, dimensions: [5, 28, 28]
#
#   **y_text**: strings containing answers of length 3: ['  2', '156']
#
#   **y_image**: a stack of images that represents the answer to a query, dimensions: [3, 28, 28]

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789+- '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 3    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer)
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)


## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (20000,) (20000, 5, 28, 28) (20000,) (20000, 3, 28, 28)
# ==================================================
# Query #8637
#
# X_text: "43-18" = y_text: "25 "
# ==================================================
# Query #526
#
# X_text: "2+63 " = y_text: "65 "
# ==================================================
# Query #3695
#
# X_text: "18-47" = y_text: "-29"
# ==================================================
# Query #8172
#
# X_text: "40+86" = y_text: "126"
# ==================================================
# Query #608
#
# X_text: "3+4  " = y_text: "7  "
# ==================================================
# Query #5392
#
# X_text: "26+96" = y_text: "122"
# ==================================================
# Query #5969
#
# X_text: "29-84" = y_text: "-55"
# ==================================================
# Query #4144
#
# X_text: "20+72" = y_text: "92 "
# ==================================================
# Query #43
#
# X_text: "0-21 " = y_text: "-21"
# ==================================================
# Query #3716
#
# X_text: "18+58" = y_text: "76 "

# %% [markdown]
# ## Helper functions
#
# The functions below will help with input/output of the data.

# %%
# One-hot encoding/decoding the text queries/answers so that they can be processed using RNNs
# You should use these functions to convert your strings and read out the output of your networks

def encode_labels(labels, max_len=3):
  n = len(labels)
  length = len(labels[0])
  char_map = dict(zip(unique_characters, range(len(unique_characters))))
  one_hot = np.zeros([n, length, len(unique_characters)])
  for i, label in enumerate(labels):
      m = np.zeros([length, len(unique_characters)])
      for j, char in enumerate(label):
          m[j, char_map[char]] = 1
      one_hot[i] = m

  return one_hot


def decode_labels(labels):
    pred = np.argmax(labels, axis=1)
    predicted = ''.join([unique_characters[i] for i in pred])

    return predicted

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

print(X_text_onehot.shape, y_text_onehot.shape)
# Out:
# (20000, 5, 13) (20000, 3, 13)

# %% [markdown]
# ---
# ---
#
# ## I. Text-to-text RNN model
#
# The following code showcases how Recurrent Neural Networks (RNNs) are built using Keras. Several new layers are going to be used:
#
# 1. LSTM
# 2. TimeDistributed
# 3. RepeatVector
#
# The code cell below explains each of these new components.
#
# <img src="https://i.ibb.co/NY7FFTc/Screenshot-2023-11-10-at-09-27-25.png" alt="Screenshot-2023-11-10-at-09-27-25" border="0" width="500"></a>

# %%
def build_text2text_model():

    # We start by initializing a sequential model
    text2text = tf.keras.Sequential()

    # "Encode" the input sequence using an RNN, producing an output of size 256.
    # In this case the size of our input vectors is [5, 13] as we have queries of length 5 and 13 unique characters. Each of these 5 elements in the query will be fed to the network one by one,
    # as shown in the image above (except with 5 elements).
    # Hint: In other applications, where your input sequences have a variable length (e.g. sentences), you would use input_shape=(None, unique_characters).
    text2text.add(LSTM(256, input_shape=(None, len(unique_characters))))

    # As the decoder RNN's input, repeatedly provide with the last output of RNN for each time step. Repeat 3 times as that's the maximum length of the output (e.g. '  1-99' = '-98')
    # when using 2-digit integers in queries. In other words, the RNN will always produce 3 characters as its output.
    text2text.add(RepeatVector(max_answer_length))

    # By setting return_sequences to True, return not only the last output but all the outputs so far in the form of (num_samples, timesteps, output_dim). This is necessary as TimeDistributed in the below expects
    # the first dimension to be the timesteps.
    text2text.add(LSTM(256, return_sequences=True))

    # Apply a dense layer to the every temporal slice of an input. For each of step of the output sequence, decide which character should be chosen.
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    # Next we compile the model using categorical crossentropy as our loss function.
    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text

# %%
## Your code (look at the assignment description for your tasks for text-to-text model):

def decode_one_hot(one_hot_encoded_query):
    return ''.join(unique_characters[np.argmax(char_vector)] for char_vector in one_hot_encoded_query)

from collections import Counter

# Modified function to collect all misclassification errors
def collect_misclassification_errors(predictions, y_test):
    errors = []
    for idx in range(len(predictions)):
        predicted_label = decode_labels(predictions[idx])
        true_label = decode_labels(y_test[idx])
        if predicted_label != true_label:
            errors.append((idx, true_label, predicted_label))
    return errors

def display_top_misclassification_mistakes(errors, X_test_encoded):
    print("Top 10 Misclassification Mistakes:")
    error_counter = Counter((true_label, predicted_label) for _, true_label, predicted_label in errors)

    for mistake, count in error_counter.most_common(10):
        true_label, predicted_label = mistake
        indices = [idx for idx, true, pred in errors if true == true_label and pred == predicted_label][:10]

        print(f"True Label: {true_label}, Predicted Label: {predicted_label}, Count: {count}")
        for idx in indices:
            query = decode_one_hot(X_test_encoded[idx])
            print(f"  Query '{query}' at Index {idx}")

# Splits for training and testing
splits = [(0.8, 0.2), (0.5, 0.5), (0.25, 0.75), (0.1, 0.9)]

# Collecting errors for each split
split_errors = {}

# Initializing dictionaries to store accuracy data
train_accuracies = {}
val_accuracies = {}

for train_size, test_size in splits:
    print(f"Training with split {train_size}-{test_size}")

    # Split the dataset
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, train_size=train_size, test_size=test_size, random_state=42)

    # Build and train the model
    model = build_text2text_model()
    history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1)

    # Storing accuracies for plotting
    train_accuracies[f"{train_size}"] = history.history['accuracy']
    val_accuracies[f"{train_size}"] = history.history['val_accuracy']

    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"Test Accuracy: {accuracy}")

    # Collect misclassification errors
    predictions = model.predict(X_test)
    split_errors[f"{train_size}"] = collect_misclassification_errors(predictions, y_test)
# Out:
# Training with split 0.8-0.2
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               276480
#
#  repeat_vector (RepeatVecto  (None, 3, 256)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed (TimeDist  (None, 3, 13)             3341
#  ributed)
#
# =================================================================
# Total params: 805133 (3.07 MB)
# Trainable params: 805133 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 225/225 [==============================] - 22s 8ms/step - loss: 1.9254 - accuracy: 0.3584 - val_loss: 1.6650 - val_accuracy: 0.4033
# Epoch 2/50
# 225/225 [==============================] - 1s 7ms/step - loss: 1.5495 - accuracy: 0.4443 - val_loss: 1.4424 - val_accuracy: 0.4658
# Epoch 3/50
# 225/225 [==============================] - 2s 8ms/step - loss: 1.3474 - accuracy: 0.5128 - val_loss: 1.2638 - val_accuracy: 0.5435
# Epoch 4/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.2520 - accuracy: 0.5462 - val_loss: 1.2204 - val_accuracy: 0.5473
# Epoch 5/50
# 225/225 [==============================] - 1s 6ms/step - loss: 1.1645 - accuracy: 0.5742 - val_loss: 1.1579 - val_accuracy: 0.5688
# Epoch 6/50
# 225/225 [==============================] - 2s 7ms/step - loss: 1.1092 - accuracy: 0.5957 - val_loss: 1.0558 - val_accuracy: 0.6148
# Epoch 7/50
# 225/225 [==============================] - 1s 6ms/step - loss: 1.0656 - accuracy: 0.6099 - val_loss: 1.0397 - val_accuracy: 0.6083
# Epoch 8/50
# 225/225 [==============================] - 1s 5ms/step - loss: 1.0356 - accuracy: 0.6184 - val_loss: 0.9853 - val_accuracy: 0.6446
# Epoch 9/50
# 225/225 [==============================] - 1s 6ms/step - loss: 0.9949 - accuracy: 0.6339 - val_loss: 0.9626 - val_accuracy: 0.6446
# Epoch 10/50
# 563/563 [==============================] - 2s 3ms/step

# %%
# Define a list of colors for the plots
colors = ['tab:blue', 'tab:green', 'tab:orange', 'tab:red']

# Plotting
plt.figure(figsize=(10, 6))
for i, train_size in enumerate(splits):
    split = train_size[0]
    color = colors[i]
    plt.plot(train_accuracies[f"{split}"], label=f"Train {split}", color=color, marker='.')
    plt.plot(val_accuracies[f"{split}"], linestyle='dotted', label=f"Validation {split}", color=color, marker='.')

plt.title("Model Accuracy vs Epochs for Different Training Set Sizes")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# For the 80/20 test split, we observe an accuracy of 99.3%. Also, the lower train splits (0.25 and 0.1) start overfitting after 30 epochs.

# %%
# Display top misclassification mistakes for each split
for train_size, errors in split_errors.items():
    print(f"\nFor Training Split {train_size}")
    display_top_misclassification_mistakes(errors, X_test)
# Out:
# For Training Split 0.8
# Top 10 Misclassification Mistakes:
# True Label: 40 , Predicted Label: 30 , Count: 7
#   Query '15+25' at Index 754
#   Query '56-16' at Index 1039
#   Query '16+24' at Index 1614
#   Query '9+31 ' at Index 1674
#   Query '1+39 ' at Index 1756
#   Query '93-53' at Index 3548
#   Query '54-14' at Index 3876
# True Label: 4  , Predicted Label: 5  , Count: 7
#   Query '43-39' at Index 1573
#   Query '88-84' at Index 1708
#   Query '33-29' at Index 1950
#   Query '42-38' at Index 2156
#   Query '89-85' at Index 2565
#   Query '73-69' at Index 3263
#   Query '78-74' at Index 3770
# True Label: 2  , Predicted Label: 3  , Count: 6
#   Query '20-18' at Index 404
#   Query '31-29' at Index 889
#   Query '18-16' at Index 2472
#   Query '41-39' at Index 2516
#   Query '28-26' at Index 2888
#   Query '48-46' at Index 3475
# True Label: 20 , Predicted Label: 10 , Count: 4
#   Query '14+6 ' at Index 1125
#   Query '16+4 ' at Index 2414
#   Query '13+7 ' at Index 3400
#   Query '93-73' at Index 3787
# True Label: -80, Predicted Label: -70, Count: 3
#   Query '16-96' at Index 546
#   Query '17-97' at Index 810
#   Query '19-99' at Index 1101
# True Label: 29 , Predicted Label: 39 , Count: 3
#   Query '14+15' at Index 611
#   Query '29+0 ' at Index 1351
#   Query '19+10' at Index 1793
# True Label: 80 , Predicted Label: 70 , Count: 3
#   Query '14+66' at Index 618
#   Query '74+6 ' at Index 1376
#   Query '76+4 ' at Index 2963
# True Label: 50 , Predicted Label: 40 , Count: 3
#   Query '26+24' at Index 1220
#   Query '15+35' at Index 1526
#   Query '16+34' at Index 3166
# True Label: 6  , Predicted Label: 5  , Count: 2
#   Query '3+3  ' at Index 333
#   Query '1+5  ' at Index 758
# True Label: 3  , Predicted Label: 4  , Count: 2
#   Query '4-1  ' at Index 382
#   Query '3-0  ' at Index 2389
#
# For Training Split 0.5
# Top 10 Misclassification Mistakes:
# True Label: 20 , Predicted Label: 10 , Count: 31
#   Query '67-47' at Index 981
#   Query '14+6 ' at Index 1125
#   Query '58-38' at Index 2094
#   Query '72-52' at Index 2251
#   Query '85-65' at Index 2326
#   Query '88-68' at Index 2753
#   Query '80-60' at Index 3144
#   Query '98-78' at Index 3212
#   Query '54-34' at Index 3290
#   Query '13+7 ' at Index 3400
# True Label: 30 , Predicted Label: 20 , Count: 25
#   Query '11+19' at Index 529
#   Query '71-41' at Index 606
#   Query '73-43' at Index 1051
#   Query '93-63' at Index 1580
#   Query '57-27' at Index 2259
#   Query '46-16' at Index 2291
#   Query '63-33' at Index 2474
#   Query '52-22' at Index 3784
#   Query '59-29' at Index 4112
#   Query '77-47' at Index 4236
# True Label: 2  , Predicted Label: 1  , Count: 25
#   Query '31-29' at Index 889
#   Query '42-40' at Index 1197
#   Query '22-20' at Index 2059
#   Query '77-75' at Index 2106
#   Query '49-47' at Index 2117
#   Query '18-16' at Index 2472
#   Query '83-81' at Index 2502
#   Query '28-26' at Index 2888
#   Query '2-0  ' at Index 2937
#   Query '48-46' at Index 3475
# True Label: 70 , Predicted Label: 60 , Count: 23
#   Query '13+57' at Index 535
#   Query '68+2 ' at Index 2070
#   Query '69+1 ' at Index 2230
#   Query '12+58' at Index 2429
#   Query '83-13' at Index 2609
#   Query '92-22' at Index 3019
#   Query '86-16' at Index 3848
#   Query '14+56' at Index 4094
#   Query '2+68 ' at Index 4155
#   Query '94-24' at Index 4369
# True Label: 59 , Predicted Label: 69 , Count: 22
#   Query '44+15' at Index 407
#   Query '43+16' at Index 819
#   Query '63-4 ' at Index 1923
#   Query '23+36' at Index 2022
#   Query '52+7 ' at Index 2296
#   Query '50+9 ' at Index 2971
#   Query '68-9 ' at Index 3239
#   Query '55+4 ' at Index 4741
#   Query '53+6 ' at Index 4846
#   Query '48+11' at Index 5062
# True Label: 6  , Predicted Label: 7  , Count: 21
#   Query '75-69' at Index 451
#   Query '96-90' at Index 1240
#   Query '69-63' at Index 1997
#   Query '36-30' at Index 2383
#   Query '65-59' at Index 3442
#   Query '10-4 ' at Index 4087
#   Query '29-23' at Index 4226
#   Query '55-49' at Index 4366
#   Query '63-57' at Index 4758
#   Query '82-76' at Index 5809
# True Label: 3  , Predicted Label: 4  , Count: 20
#   Query '4-1  ' at Index 382
#   Query '36-33' at Index 773
#   Query '34-31' at Index 1500
#   Query '55-52' at Index 2510
#   Query '33-30' at Index 3176
#   Query '38-35' at Index 4003
#   Query '24-21' at Index 4247
#   Query '54-51' at Index 4845
#   Query '47-44' at Index 4993
#   Query '48-45' at Index 5054
# True Label: 4  , Predicted Label: 5  , Count: 15
#   Query '61-57' at Index 1452
#   Query '52-48' at Index 1485
#   Query '43-39' at Index 1573
#   Query '91-87' at Index 1839
#   Query '33-29' at Index 1950
#   Query '42-38' at Index 2156
#   Query '73-69' at Index 3263
#   Query '71-67' at Index 4887
#   Query '90-86' at Index 5159
#   Query '0+4  ' at Index 5375
# True Label: -8 , Predicted Label: -7 , Count: 13
#   Query '31-39' at Index 874
#   Query '50-58' at Index 1703
#   Query '51-59' at Index 3878
#   Query '60-68' at Index 4305
#   Query '70-78' at Index 4665
#   Query '30-38' at Index 5885
#   Query '10-18' at Index 5902
#   Query '41-49' at Index 6225
#   Query '20-28' at Index 6848
#   Query '71-79' at Index 7155
# True Label: 129, Predicted Label: 139, Count: 12
#   Query '68+61' at Index 274
#   Query '38+91' at Index 1173
#   Query '36+93' at Index 2398
#   Query '57+72' at Index 3392
#   Query '78+51' at Index 4194
#   Query '37+92' at Index 4816
#   Query '97+32' at Index 5617
#   Query '98+31' at Index 7032
#   Query '47+82' at Index 7549
#   Query '39+90' at Index 8659
#
# For Training Split 0.25
# Top 10 Misclassification Mistakes:
# True Label: 9  , Predicted Label: 1  , Count: 61
#   Query '80-71' at Index 74
#   Query '77-68' at Index 129
#   Query '23-14' at Index 163
#   Query '37-28' at Index 994
#   Query '87-78' at Index 1009
#   Query '35-26' at Index 1123
#   Query '49-40' at Index 1142
#   Query '65-56' at Index 1731
#   Query '10-1 ' at Index 1744
#   Query '60-51' at Index 2336
# True Label: 8  , Predicted Label: 1  , Count: 59
#   Query '37-29' at Index 21
#   Query '5+3  ' at Index 242
#   Query '7+1  ' at Index 595
#   Query '76-68' at Index 737
#   Query '52-44' at Index 965
#   Query '83-75' at Index 1084
#   Query '45-37' at Index 1625
#   Query '72-64' at Index 1732
#   Query '30-22' at Index 1914
#   Query '48-40' at Index 2511
# True Label: 25 , Predicted Label: 26 , Count: 59
#   Query '50-25' at Index 461
#   Query '85-60' at Index 877
#   Query '57-32' at Index 1909
#   Query '86-61' at Index 1999
#   Query '13+12' at Index 2427
#   Query '77-52' at Index 3386
#   Query '76-51' at Index 3461
#   Query '59-34' at Index 3622
#   Query '71-46' at Index 3660
#   Query '20+5 ' at Index 3916
# True Label: 35 , Predicted Label: 36 , Count: 56
#   Query '41-6 ' at Index 213
#   Query '2+33 ' at Index 779
#   Query '7+28 ' at Index 825
#   Query '95-60' at Index 1115
#   Query '64-29' at Index 1345
#   Query '63-28' at Index 2237
#   Query '3+32 ' at Index 2951
#   Query '82-47' at Index 2952
#   Query '24+11' at Index 3178
#   Query '4+31 ' at Index 4329
# True Label: 55 , Predicted Label: 56 , Count: 53
#   Query '69-14' at Index 52
#   Query '42+13' at Index 320
#   Query '10+45' at Index 565
#   Query '31+24' at Index 691
#   Query '27+28' at Index 1254
#   Query '28+27' at Index 1415
#   Query '85-30' at Index 1631
#   Query '82-27' at Index 1736
#   Query '94-39' at Index 2269
#   Query '80-25' at Index 2910
# True Label: 65 , Predicted Label: 66 , Count: 50
#   Query '16+49' at Index 143
#   Query '38+27' at Index 586
#   Query '81-16' at Index 788
#   Query '75-10' at Index 961
#   Query '15+50' at Index 1234
#   Query '11+54' at Index 1565
#   Query '83-18' at Index 2410
#   Query '3+62 ' at Index 2540
#   Query '71-6 ' at Index 2642
#   Query '87-22' at Index 3269
# True Label: 45 , Predicted Label: 46 , Count: 49
#   Query '84-39' at Index 663
#   Query '88-43' at Index 686
#   Query '61-16' at Index 1517
#   Query '77-32' at Index 1661
#   Query '80-35' at Index 1664
#   Query '31+14' at Index 2463
#   Query '27+18' at Index 2594
#   Query '71-26' at Index 3006
#   Query '87-42' at Index 3191
#   Query '13+32' at Index 3408
# True Label: 2  , Predicted Label: 1  , Count: 47
#   Query '74-72' at Index 294
#   Query '46-44' at Index 1153
#   Query '77-75' at Index 2106
#   Query '49-47' at Index 2117
#   Query '83-81' at Index 2502
#   Query '64-62' at Index 2698
#   Query '28-26' at Index 2888
#   Query '48-46' at Index 3475
#   Query '95-93' at Index 4213
#   Query '37-35' at Index 4633
# True Label: -17, Predicted Label: -16, Count: 44
#   Query '40-57' at Index 9
#   Query '81-98' at Index 91
#   Query '47-64' at Index 537
#   Query '29-46' at Index 1253
#   Query '0-17 ' at Index 1549
#   Query '82-99' at Index 1759
#   Query '6-23 ' at Index 2563
#   Query '77-94' at Index 2690
#   Query '80-97' at Index 2714
#   Query '73-90' at Index 2889
# True Label: -15, Predicted Label: -16, Count: 43
#   Query '30-45' at Index 1430
#   Query '0-15 ' at Index 1639
#   Query '14-29' at Index 1688
#   Query '16-31' at Index 1987
#   Query '60-75' at Index 2176
#   Query '22-37' at Index 2579
#   Query '35-50' at Index 2732
#   Query '25-40' at Index 2874
#   Query '10-25' at Index 3729
#   Query '80-95' at Index 4095
#
# For Training Split 0.1
# Top 10 Misclassification Mistakes:
# True Label: 9  , Predicted Label: 1  , Count: 82
#   Query '80-71' at Index 74
#   Query '77-68' at Index 129
#   Query '23-14' at Index 163
#   Query '96-87' at Index 722
#   Query '37-28' at Index 994
#   Query '87-78' at Index 1009
#   Query '35-26' at Index 1123
#   Query '49-40' at Index 1142
#   Query '19-10' at Index 1922
#   Query '60-51' at Index 2336
# True Label: 8  , Predicted Label: 1  , Count: 76
#   Query '37-29' at Index 21
#   Query '5+3  ' at Index 242
#   Query '44-36' at Index 468
#   Query '7+1  ' at Index 595
#   Query '76-68' at Index 737
#   Query '52-44' at Index 965
#   Query '83-75' at Index 1084
#   Query '59-51' at Index 1464
#   Query '45-37' at Index 1625
#   Query '72-64' at Index 1732
# True Label: 10 , Predicted Label: 1  , Count: 75
#   Query '4+6  ' at Index 188
#   Query '8+2  ' at Index 210
#   Query '1+9  ' at Index 224
#   Query '58-48' at Index 460
#   Query '33-23' at Index 543
#   Query '35-25' at Index 676
#   Query '75-65' at Index 727
#   Query '20-10' at Index 912
#   Query '80-70' at Index 913
#   Query '62-52' at Index 1333
# True Label: 11 , Predicted Label: 1  , Count: 71
#   Query '87-76' at Index 23
#   Query '48-37' at Index 266
#   Query '60-49' at Index 269
#   Query '93-82' at Index 490
#   Query '28-17' at Index 1467
#   Query '37-26' at Index 1933
#   Query '31-20' at Index 2224
#   Query '84-73' at Index 2311
#   Query '40-29' at Index 2487
#   Query '76-65' at Index 2622
# True Label: -7 , Predicted Label: -1 , Count: 71
#   Query '35-42' at Index 64
#   Query '66-73' at Index 444
#   Query '77-84' at Index 701
#   Query '73-80' at Index 729
#   Query '17-24' at Index 731
#   Query '47-54' at Index 733
#   Query '85-92' at Index 879
#   Query '68-75' at Index 989
#   Query '30-37' at Index 1078
#   Query '3-10 ' at Index 1559
# True Label: 7  , Predicted Label: 1  , Count: 70
#   Query '6+1  ' at Index 833
#   Query '21-14' at Index 1243
#   Query '89-82' at Index 1461
#   Query '76-69' at Index 2337
#   Query '2+5  ' at Index 2432
#   Query '68-61' at Index 2460
#   Query '60-53' at Index 2605
#   Query '71-64' at Index 2689
#   Query '48-41' at Index 2752
#   Query '83-76' at Index 2916
# True Label: -8 , Predicted Label: -1 , Count: 69
#   Query '5-13 ' at Index 252
#   Query '34-42' at Index 378
#   Query '31-39' at Index 874
#   Query '43-51' at Index 1617
#   Query '50-58' at Index 1703
#   Query '85-93' at Index 1965
#   Query '59-67' at Index 2121
#   Query '84-92' at Index 2122
#   Query '22-30' at Index 3052
#   Query '86-94' at Index 3060
# True Label: 12 , Predicted Label: 1  , Count: 66
#   Query '72-60' at Index 278
#   Query '58-46' at Index 1266
#   Query '37-25' at Index 1746
#   Query '77-65' at Index 2550
#   Query '76-64' at Index 2639
#   Query '84-72' at Index 2744
#   Query '49-37' at Index 3518
#   Query '57-45' at Index 3634
#   Query '51-39' at Index 3873
#   Query '75-63' at Index 4038
# True Label: -6 , Predicted Label: -1 , Count: 63
#   Query '18-24' at Index 29
#   Query '69-75' at Index 419
#   Query '85-91' at Index 478
#   Query '55-61' at Index 1492
#   Query '74-80' at Index 1702
#   Query '7-13 ' at Index 1789
#   Query '11-17' at Index 1831
#   Query '53-59' at Index 2118
#   Query '86-92' at Index 2119
#   Query '36-42' at Index 2128
# True Label: 97 , Predicted Label: 90 , Count: 61
#   Query '77+20' at Index 40
#   Query '10+87' at Index 486
#   Query '84+13' at Index 1316
#   Query '65+32' at Index 1597
#   Query '25+72' at Index 1763
#   Query '21+76' at Index 2063
#   Query '85+12' at Index 2169
#   Query '56+41' at Index 2170
#   Query '30+67' at Index 2228
#   Query '48+49' at Index 2316

# %% [markdown]
# ---
# ---
#
# ## II. Image to text RNN Model
#
# Hint: There are two ways of building the encoder for such a model - again by using the regular LSTM cells (with flattened images as vectors) or recurrect convolutional layers [ConvLSTM2D](https://keras.io/api/layers/recurrent_layers/conv_lstm2d/).
#
# The goal here is to use **X_img** as inputs and **y_text** as outputs.

# %%
### 1.3 Image-to-text model

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import RMSprop

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

def build_image_to_text_model():
    input_shape = (5, 28, 28, 1)  # 5 images, each 28x28 pixels, 1 channel (grayscale)

    # Input layer for image sequences
    input_layer = Input(shape=input_shape)

    # CNN for feature extraction from each image, wrapped in TimeDistributed
    cnn = TimeDistributed(Conv2D(32, kernel_size=(3, 3), activation='relu'))(input_layer)
    cnn = TimeDistributed(Conv2D(64, kernel_size=(3, 3), activation='relu'))(cnn)
    cnn = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(cnn)
    cnn = TimeDistributed(Dropout(0.25))(cnn)
    cnn = TimeDistributed(Flatten())(cnn)
    cnn = TimeDistributed(Dense(128, activation='relu'))(cnn)
    cnn = TimeDistributed(Dropout(0.5))(cnn)

    # RNN (LSTM) for understanding the sequence
    lstm = LSTM(128)(cnn)

    # RepeatVector to repeat context for each time step in the output
    repeated_context = RepeatVector(max_answer_length)(lstm)

    # Another LSTM layer with return_sequences=True for generating the sequence
    lstm_output = LSTM(128, return_sequences=True)(repeated_context)

    # Dense layer to output the textual answer in one-hot format at each time step
    output = TimeDistributed(Dense(len(unique_characters), activation='softmax'))(lstm_output)


    # Compile the model
    model = Model(inputs=input_layer, outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer= 'adam', metrics=['accuracy'])

    model.summary()

    return model

# Prepare image data for the model (reshape and normalize)
X_img_reshaped = X_img.reshape((-1, 5, 28, 28, 1)) / 255.0

# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(X_img_reshaped, y_text_onehot, train_size=0.8, test_size=0.2, random_state=42)

# Build and train the image-to-text model
image_to_text_model = build_image_to_text_model()
history = image_to_text_model.fit(X_train, y_train, epochs=100, batch_size=64, validation_split=0.1)

# Evaluate the model
loss, accuracy = image_to_text_model.evaluate(X_test, y_test)
print(f"Image-to-Text Model Test Accuracy: {accuracy}")

# Plotting the learning curves
plt.figure(figsize=(12, 6))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 5, 28, 28, 1)]    0
#
#  time_distributed_48 (TimeDi  (None, 5, 26, 26, 32)    320
#  stributed)
#
#  time_distributed_49 (TimeDi  (None, 5, 24, 24, 64)    18496
#  stributed)
#
#  time_distributed_50 (TimeDi  (None, 5, 12, 12, 64)    0
#  stributed)
#
#  time_distributed_51 (TimeDi  (None, 5, 12, 12, 64)    0
#  stributed)
#
#  time_distributed_52 (TimeDi  (None, 5, 9216)          0
#  stributed)
#
#  time_distributed_53 (TimeDi  (None, 5, 128)           1179776
#  stributed)
#
#  time_distributed_54 (TimeDi  (None, 5, 128)           0
#  stributed)
#
#  lstm_12 (LSTM)              (None, 128)               131584
#
#  repeat_vector_6 (RepeatVect  (None, 3, 128)           0
#  or)
#
#  lstm_13 (LSTM)              (None, 3, 128)            131584
#
#  time_distributed_55 (TimeDi  (None, 3, 13)            1677
#  stributed)
#
# =================================================================
# Total params: 1,463,437
# Trainable params: 1,463,437
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 225/225 [==============================] - 65s 275ms/step - loss: 2.1079 - accuracy: 0.3151 - val_loss: 2.0570 - val_accuracy: 0.2994
# Epoch 2/100
# 225/225 [==============================] - 61s 273ms/step - loss: 2.0442 - accuracy: 0.3250 - val_loss: 2.0519 - val_accuracy: 0.2996
# Epoch 3/100
# 225/225 [==============================] - 61s 272ms/step - loss: 2.0424 - accuracy: 0.3241 - val_loss: 2.0476 - val_accuracy: 0.3219
# Epoch 4/100
# 225/225 [==============================] - 61s 272ms/step - loss: 2.0423 - accuracy: 0.3253 - val_loss: 2.0500 - val_accuracy: 0.3244
# Epoch 5/100
# 225/225 [==============================] - 61s 273ms/step - loss: 2.0416 - accuracy: 0.3248 - val_loss: 2.0503 - val_accuracy: 0.3219
# Epoch 6/100
# 225/225 [==============================] - 60s 268ms/step - loss: 2.0388 - accuracy: 0.3256 - val_loss: 2.0377 - val_accuracy: 0.3315
# Epoch 7/100
# 225/225 [==============================] - 60s 267ms/step - loss: 1.9754 - accuracy: 0.3598 - val_loss: 1.8887 - val_accuracy: 0.3900
# Epoch 8/100
# 225/225 [==============================] - 63s 280ms/step - loss: 0.3806 - accuracy: 0.8930 - val_loss: 0.4307 - val_accuracy: 0.8808
# Epoch 86/100
# 225/225 [==============================] - 63s 282ms/step - loss: 0.3734 - accuracy: 0.8972 - val_loss: 0.3970 - val_accuracy: 0.8927
# Epoch 87/100
# 225/225 [==============================] - 63s 281ms/step - loss: 0.3678 - accuracy: 0.9004 - val_loss: 0.4043 - val_accuracy: 0.8956
# Epoch 88/100
# 225/225 [==============================] - 63s 282ms/step - loss: 0.3513 - accuracy: 0.9058 - val_loss: 0.4121 - val_accuracy: 0.8873
# Epoch 89/100
# 225/225 [==============================] - 63s 282ms/step - loss: 0.3525 - accuracy: 0.9024 - val_loss: 0.4012 - val_accuracy: 0.8956
# Epoch 90/100
# 225/225 [==============================] - 63s 282ms/step - loss: 0.3458 - accuracy: 0.9037 - val_loss: 0.3957 - val_accuracy: 0.8971
# Epoch 91/100
# 225/225 [==============================] - 63s 281ms/step - loss: 0.3387 - accuracy: 0.9061 - val_loss: 0.3940 - val_accuracy: 0.8952
# Epoch 92/100
# 225/225 [==============================] - 63s 281ms/step - loss: 0.3260 - accuracy: 0.9117 - val_loss: 0.3891 - val_accuracy: 0.9000
# Epoch 93/100
# 225/225 [==============================] - 63s 281ms/step - loss: 0.3207 - accuracy: 0.9133 - val_loss: 0.3801 - val_accuracy: 0.9002
# Epoch 94/100
# 225/225 [==============================] - 63s 281ms/step - loss: 0.3132 - accuracy: 0.9163 - val_loss: 0.3851 - val_accuracy: 0.8983
# Epoch 95/100
# 225/225 [==============================] - 63s 280ms/step - loss: 0.3091 - accuracy: 0.9167 - val_loss: 0.3768 - val_accuracy: 0.8965
# Epoch 96/100
# 225/225 [==============================] - 63s 279ms/step - loss: 0.3042 - accuracy: 0.9166 - val_loss: 0.3857 - val_accuracy: 0.8998
# Epoch 97/100
# 225/225 [==============================] - 63s 280ms/step - loss: 0.3007 - accuracy: 0.9196 - val_loss: 0.3774 - val_accuracy: 0.9000
# Epoch 98/100
# 225/225 [==============================] - 63s 280ms/step - loss: 0.2882 - accuracy: 0.9213 - val_loss: 0.3656 - val_accuracy: 0.9058
# Epoch 99/100
# 225/225 [==============================] - 63s 279ms/step - loss: 0.2872 - accuracy: 0.9225 - val_loss: 0.3656 - val_accuracy: 0.9027
# Epoch 100/100
# 225/225 [==============================] - 63s 279ms/step - loss: 0.2858 - accuracy: 0.9233 - val_loss: 0.3545 - val_accuracy: 0.9058
# 125/125 [==============================] - 5s 32ms/step - loss: 0.3437 - accuracy: 0.9142
# Image-to-Text Model Test Accuracy: 0.9141666889190674

# %% [markdown]
# ---
# ---
#
# ## III. Text to image RNN Model
#
# Hint: to make this model work really well you could use deconvolutional layers in your decoder (you might need to look up ***Conv2DTranspose*** layer). However, regular vector-based decoder will work as well.
#
# The goal here is to use **X_text** as inputs and **y_img** as outputs.

# %% [markdown]
# # 1.4: Build text-to-image model (optimized model, we switched task 1.4 and 1.5)

# %%
# Repeated code to define parameters:

unique_characters = '0123456789+- '
highest_integer = 99
max_int_length = len(str(highest_integer))
max_query_length = max_int_length * 2 + 1
max_answer_length = 3

# Actual code:

def build_text_to_image_model():
    # Text input encoding
    text_input = Input(shape=(max_query_length, len(unique_characters)))
    encoded_text = LSTM(256)(text_input)
    repeated_context = RepeatVector(3)(encoded_text)  # Assuming the output is 3 images

    # Decoding into image features
    decoded_images = LSTM(256, return_sequences=True)(repeated_context)
    decoded_images = TimeDistributed(Dense(7 * 7 * 64))(decoded_images)  # Adjusted size

    # Reshaping to form intermediate images
    images = Reshape((3, 7, 7, 64))(decoded_images)

    # Upsampling to reach the desired image size (28x28)
    images = TimeDistributed(Conv2DTranspose(64, (3, 3), strides=(2, 2), padding='same', activation='relu'))(images)
    images = Dropout(0.5)(images)
    images = TimeDistributed(Conv2DTranspose(64, (3, 3), strides=(1, 1), padding='same', activation='relu'))(images)
    images = Dropout(0.5)(images)
    images = TimeDistributed(Conv2DTranspose(32, (3, 3), strides=(1, 1), padding='same', activation='relu'))(images)
    images = Dropout(0.5)(images)
    images = TimeDistributed(Conv2DTranspose(32, (3, 3), strides=(1, 1), padding='same', activation='relu'))(images)
    images = Dropout(0.5)(images)
    images = TimeDistributed(Conv2DTranspose(32, (3, 3), strides=(1, 1), padding='same', activation='relu'))(images) # Remove with drop ***
    images = Dropout(0.5)(images)
    images = TimeDistributed(Conv2DTranspose(1, (3, 3), strides=(2, 2), padding='same', activation='sigmoid'))(images)

    # Compile the model
    model = Model(inputs=text_input, outputs=images)
    model.compile(optimizer= 'adam', loss='mse')
    model.summary()

    return model


# Encode the entire dataset
X_text_encoded = encode_labels(X_text)

# Split the encoded data
X_text_train, X_text_test, y_img_train, y_img_test = train_test_split(X_text_encoded, y_img, test_size=0.2, random_state=42)

# Build the text-to-image model
text_to_image_model = build_text_to_image_model()

# Fit the model using the training data
text_to_image_model.fit(X_text_train, y_img_train, epochs=200, batch_size=64, validation_split=0.1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 13)]           0
#
#  lstm (LSTM)                 (None, 256)               276480
#
#  repeat_vector (RepeatVecto  (None, 3, 256)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed (TimeDist  (None, 3, 3136)           805952
#  ributed)
#
#  reshape (Reshape)           (None, 3, 7, 7, 64)       0
#
#  time_distributed_1 (TimeDi  (None, 3, 14, 14, 64)     36928
#  stributed)
#
#  dropout (Dropout)           (None, 3, 14, 14, 64)     0
#
#  time_distributed_2 (TimeDi  (None, 3, 14, 14, 64)     36928
#  stributed)
#
#  dropout_1 (Dropout)         (None, 3, 14, 14, 64)     0
#
#  time_distributed_3 (TimeDi  (None, 3, 14, 14, 32)     18464
#  stributed)
#
#  dropout_2 (Dropout)         (None, 3, 14, 14, 32)     0
#
#  time_distributed_4 (TimeDi  (None, 3, 14, 14, 32)     9248
#  stributed)
#
#  dropout_3 (Dropout)         (None, 3, 14, 14, 32)     0
#
#  time_distributed_5 (TimeDi  (None, 3, 14, 14, 32)     9248
#  stributed)
#
#  dropout_4 (Dropout)         (None, 3, 14, 14, 32)     0
#
#  time_distributed_6 (TimeDi  (None, 3, 28, 28, 1)      289
#  stributed)
#
# =================================================================
# Total params: 1718849 (6.56 MB)
# Trainable params: 1718849 (6.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1
200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0271 - val_loss: 0.0524
# Epoch 178/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0269 - val_loss: 0.0522
# Epoch 179/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0269 - val_loss: 0.0523
# Epoch 180/200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0266 - val_loss: 0.0526
# Epoch 181/200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0265 - val_loss: 0.0530
# Epoch 182/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0264 - val_loss: 0.0528
# Epoch 183/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0263 - val_loss: 0.0529
# Epoch 184/200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0262 - val_loss: 0.0532
# Epoch 185/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0261 - val_loss: 0.0527
# Epoch 186/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0259 - val_loss: 0.0528
# Epoch 187/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0258 - val_loss: 0.0531
# Epoch 188/200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0257 - val_loss: 0.0531
# Epoch 189/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0256 - val_loss: 0.0538
# Epoch 190/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0256 - val_loss: 0.0534
# Epoch 191/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0254 - val_loss: 0.0540
# Epoch 192/200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0253 - val_loss: 0.0539
# Epoch 193/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0252 - val_loss: 0.0540
# Epoch 194/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0250 - val_loss: 0.0535
# Epoch 195/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0249 - val_loss: 0.0541
# Epoch 196/200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0248 - val_loss: 0.0540
# Epoch 197/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0248 - val_loss: 0.0543
# Epoch 198/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0246 - val_loss: 0.0539
# Epoch 199/200
# 225/225 [==============================] - 3s 15ms/step - loss: 0.0245 - val_loss: 0.0545
# Epoch 200/200
# 225/225 [==============================] - 4s 16ms/step - loss: 0.0244 - val_loss: 0.0549

# %%
import random

random.seed(42)

def decode_one_hot(one_hot_encoded_query):
    return ''.join(unique_characters[np.argmax(char_vector)] for char_vector in one_hot_encoded_query)

def plot_images(images, title):
    num_images = images.shape[0]
    plt.figure(figsize=(5, 1))  # Adjust the figure size
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.axis('off')

    plt.subplots_adjust(top=0.8)  # Adjust the top spacing
    plt.suptitle(title, y=1.05)  # Adjust the title position
    plt.show()

num_samples_to_visualize = 10
indices = np.random.choice(range(len(X_text_test)), num_samples_to_visualize, replace=False)

for idx in indices:
    # Get the one-hot encoded text query and decode it
    text_query_encoded = X_text_test[idx]
    text_query = decode_one_hot(text_query_encoded)

    # Generate images using the model
    predicted_images = text_to_image_model.predict(text_query_encoded[np.newaxis, ...])

    # Plot the predicted images with the query
    plot_images(predicted_images.squeeze(), f"Generated Images for Query: '{text_query}'")

    # Optionally, plot the actual images for comparison
    actual_images = y_img_test[idx]
    plot_images(actual_images.squeeze(), f"Actual Images for Query: '{text_query}'")
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %% [markdown]
# # 1.5 Text-to-image model with single LSTM layer (we switched 1.4 and 1.5)

# %%
def build_text_to_image_model():
    # Text input encoding
    text_input = Input(shape=(max_query_length, len(unique_characters)))
    encoded_text = LSTM(256)(text_input)
    repeated_context = RepeatVector(3)(encoded_text)  # Assuming the output is 3 images

    # Decoding into image features
    decoded_images = LSTM(256, return_sequences=True)(repeated_context)
    decoded_images = TimeDistributed(Dense(7 * 7 * 64))(decoded_images)  # Adjusted size

    # Reshaping to form intermediate images
    images = Reshape((3, 7, 7, 64))(decoded_images)

    # Upsampling to reach the desired image size (28x28)
    images = TimeDistributed(Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same', activation='relu'))(images)
    images = TimeDistributed(Conv2DTranspose(1, (3, 3), strides=(2, 2), padding='same', activation='sigmoid'))(images)

    # Compile the model
    model = Model(inputs=text_input, outputs=images)
    model.compile(optimizer='adam', loss='mse')
    model.summary()

    return model


# Encode the entire dataset
X_text_encoded = encode_labels(X_text)

# Split the encoded data
X_text_train, X_text_test, y_img_train, y_img_test = train_test_split(X_text_encoded, y_img, test_size=0.2, random_state=42)

# Build the text-to-image model
text_to_image_model = build_text_to_image_model()

# Fit the model using the training data
text_to_image_model.fit(X_text_train, y_img_train, epochs=100, batch_size=64, validation_split=0.1)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 13)]           0
#
#  lstm_2 (LSTM)               (None, 256)               276480
#
#  repeat_vector_1 (RepeatVec  (None, 3, 256)            0
#  tor)
#
#  lstm_3 (LSTM)               (None, 3, 256)            525312
#
#  time_distributed_8 (TimeDi  (None, 3, 3136)           805952
#  stributed)
#
#  reshape (Reshape)           (None, 3, 7, 7, 64)       0
#
#  time_distributed_9 (TimeDi  (None, 3, 14, 14, 32)     18464
#  stributed)
#
#  time_distributed_10 (TimeD  (None, 3, 28, 28, 1)      289
#  istributed)
#
# =================================================================
# Total params: 1626497 (6.20 MB)
# Trainable params: 1626497 (6.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 225/225 [==============================] - 7s 11ms/step - loss: 0.0757 - val_loss: 0.0551
# Epoch 2/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0542 - val_loss: 0.0539
# Epoch 3/100
# 225/225 [==============================] - 2s 9ms/step - loss: 0.0533 - val_loss: 0.0525
# Epoch 4/100
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0503 - val_loss: 0.0491
# Epoch 5/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0485 - val_loss: 0.0483
# Epoch 6/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0478 - val_loss: 0.0488
# Epoch 7/100
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0474 - val_loss: 0.0479
# Epoch 8/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0474 - val_loss: 0.0473
# Epoch 9/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0470 - val_loss: 0.0471
# Epoch 10/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0468 - val_loss: 0.0471
# Epoch 11/100
# 225/225 [==============================] - 2s 9ms/step - loss: 0.0466 - val_loss: 0.0466
# Epoch 12/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0465 - val_loss: 0.0465
# Epoch 13/100
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0463 - val_loss: 0.0463
# Epoch 14/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0461 - val_loss: 0.0462
# Epoch 15/100
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0461 - val_loss: 0.0461
# Epoch 16/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0459 - val_loss: 0.0460
# Epoch 17/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0459 - val_loss: 0.0459
# Epoch 18/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0457 - val_loss: 0.0459
# Epoch 19/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0455 - val_loss: 0.0456
# Epoch 20/100
# 225/225 [==============================] - 2s 9ms/step - loss: 0.0454 - val_loss: 0.0457
# Epoch 21/100
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0453 - val_loss: 0.0454
# Epoch 22/100
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0452 - val_loss: 0.0454
# Epoch 23/100
# 225/225 [==============================] - 2s 10ms/step - loss: 0.0451 - val_loss: 0.0452
# Epoch 24/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.
100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0381 - val_loss: 0.0409
# Epoch 65/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0379 - val_loss: 0.0405
# Epoch 66/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0378 - val_loss: 0.0407
# Epoch 67/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0377 - val_loss: 0.0408
# Epoch 68/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0375 - val_loss: 0.0407
# Epoch 69/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0374 - val_loss: 0.0409
# Epoch 70/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0373 - val_loss: 0.0409
# Epoch 71/100
# 225/225 [==============================] - 2s 9ms/step - loss: 0.0372 - val_loss: 0.0409
# Epoch 72/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0370 - val_loss: 0.0409
# Epoch 73/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0369 - val_loss: 0.0413
# Epoch 74/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0369 - val_loss: 0.0411
# Epoch 75/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0365 - val_loss: 0.0412
# Epoch 76/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0364 - val_loss: 0.0413
# Epoch 77/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0363 - val_loss: 0.0414
# Epoch 78/100
# 225/225 [==============================] - 1s 7ms/step - loss: 0.0362 - val_loss: 0.0416
# Epoch 79/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0360 - val_loss: 0.0417
# Epoch 80/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0358 - val_loss: 0.0417
# Epoch 81/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0357 - val_loss: 0.0418
# Epoch 82/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0356 - val_loss: 0.0421
# Epoch 83/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0354 - val_loss: 0.0422
# Epoch 84/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0351 - val_loss: 0.0422
# Epoch 85/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0349 - val_loss: 0.0423
# Epoch 86/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0347 - val_loss: 0.0425
# Epoch 87/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0347 - val_loss: 0.0425
# Epoch 88/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0344 - val_loss: 0.0427
# Epoch 89/100
# 225/225 [==============================] - 2s 9ms/step - loss: 0.0343 - val_loss: 0.0429
# Epoch 90/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0340 - val_loss: 0.0430
# Epoch 91/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0338 - val_loss: 0.0435
# Epoch 92/100
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0337 - val_loss: 0.0435
# Epoch 93/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0334 - val_loss: 0.0436
# Epoch 94/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0331 - val_loss: 0.0439
# Epoch 95/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0331 - val_loss: 0.0441
# Epoch 96/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0327 - val_loss: 0.0441
# Epoch 97/100
# 225/225 [==============================] - 2s 9ms/step - loss: 0.0325 - val_loss: 0.0446
# Epoch 98/100
# 225/225 [==============================] - 2s 8ms/step - loss: 0.0324 - val_loss: 0.0447
# Epoch 99/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0322 - val_loss: 0.0447
# Epoch 100/100
# 225/225 [==============================] - 2s 7ms/step - loss: 0.0318 - val_loss: 0.0450

# %%
def decode_one_hot(one_hot_encoded_query):
    return ''.join(unique_characters[np.argmax(char_vector)] for char_vector in one_hot_encoded_query)

def plot_images(images, title):
    num_images = images.shape[0]
    plt.figure(figsize=(5, 1))  # Adjust the figure size
    for i in range(num_images):
        plt.subplot(1, num_images, i + 1)
        plt.imshow(images[i].squeeze(), cmap='gray')
        plt.axis('off')

    plt.subplots_adjust(top=0.8)  # Adjust the top spacing
    plt.suptitle(title, y=1.05)  # Adjust the title position
    plt.show()

num_samples_to_visualize = 10
indices = np.random.choice(range(len(X_text_test)), num_samples_to_visualize, replace=False)

for idx in indices:
    # Get the one-hot encoded text query and decode it
    text_query_encoded = X_text_test[idx]
    text_query = decode_one_hot(text_query_encoded)

    # Generate images using the model
    predicted_images = text_to_image_model.predict(text_query_encoded[np.newaxis, ...])

    # Plot the predicted images with the query
    plot_images(predicted_images.squeeze(), f"Generated Images for Query: '{text_query}'")

    # Optionally, plot the actual images for comparison
    actual_images = y_img_test[idx]
    plot_images(actual_images.squeeze(), f"Actual Images for Query: '{text_query}'")
# Out:
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step

# %% [markdown]
# ---
# ---
# ---
#
# # Part 2: Multiplication
# The cell below will create the multiplication dataset used in this part of the assignment.

# %%
# Illustrate the generated query/answer pairs

unique_characters = '0123456789* '       # All unique characters that are used in the queries (13 in total: digits 0-9, 2 operands [+, -], and a space character ' '.)
highest_integer = 99                      # Highest value of integers contained in the queries

max_int_length = len(str(highest_integer))# Maximum number of characters in an integer
max_query_length = max_int_length * 2 + 1 # Maximum length of the query string (consists of two integers and an operand [e.g. '22+10'])
max_answer_length = 5    # Maximum length of the answer string (the longest resulting query string is ' 1-99'='-98')

# Create the data (might take around a minute)
(MNIST_data, MNIST_labels), _ = tf.keras.datasets.mnist.load_data()
X_text, X_img, y_text, y_img = create_data(highest_integer, operands=['*'])
print(X_text.shape, X_img.shape, y_text.shape, y_img.shape)


## Display the samples that were created
def display_sample(n):
    labels = ['X_img:', 'y_img:']
    for i, data in enumerate([X_img, y_img]):
        plt.subplot(1,2,i+1)
        # plt.set_figheight(15)
        plt.axis('off')
        plt.title(labels[i])
        plt.imshow(np.hstack(data[n]), cmap='gray')
    print('='*50, f'\nQuery #{n}\n\nX_text: "{X_text[n]}" = y_text: "{y_text[n]}"')
    plt.show()

for _ in range(10):
    display_sample(np.random.randint(0, 10000, 1)[0])
# Out:
# (10000,) (10000, 5, 28, 28) (10000,) (10000, 5, 28, 28)
# ==================================================
# Query #328
#
# X_text: "3*28 " = y_text: "84   "
# ==================================================
# Query #8061
#
# X_text: "80*61" = y_text: "4880 "
# ==================================================
# Query #5382
#
# X_text: "53*82" = y_text: "4346 "
# ==================================================
# Query #1615
#
# X_text: "16*15" = y_text: "240  "
# ==================================================
# Query #8950
#
# X_text: "89*50" = y_text: "4450 "
# ==================================================
# Query #9866
#
# X_text: "98*66" = y_text: "6468 "
# ==================================================
# Query #294
#
# X_text: "2*94 " = y_text: "188  "
# ==================================================
# Query #2755
#
# X_text: "27*55" = y_text: "1485 "
# ==================================================
# Query #3641
#
# X_text: "36*41" = y_text: "1476 "
# ==================================================
# Query #3815
#
# X_text: "38*15" = y_text: "570  "

# %% [markdown]
# # 2.2 Text-to-text multiplication model

# %%
## Your code

X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

### Text-to-text model multiplication

def build_text2text_multiplication_model():
    text2text = tf.keras.Sequential()

    # Input shape: max_query_length, len(unique_characters)
    text2text.add(LSTM(256, input_shape=(max_query_length, len(unique_characters))))

    # Output length for multiplication might be different
    text2text.add(RepeatVector(max_answer_length))

    text2text.add(LSTM(256, return_sequences=True))
    text2text.add(TimeDistributed(Dense(len(unique_characters), activation='softmax')))

    text2text.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    text2text.summary()

    return text2text


def decode_one_hot(one_hot_encoded_query):
    return ''.join(unique_characters[np.argmax(char_vector)] for char_vector in one_hot_encoded_query)

from collections import Counter

# Modified function to collect all misclassification errors
def collect_misclassification_errors(predictions, y_test):
    errors = []
    for idx in range(len(predictions)):
        predicted_label = decode_labels(predictions[idx])
        true_label = decode_labels(y_test[idx])
        if predicted_label != true_label:
            errors.append((idx, true_label, predicted_label))
    return errors

def display_top_misclassification_mistakes(errors, X_test_encoded):
    print("Top 10 Misclassification Mistakes:")
    error_counter = Counter((true_label, predicted_label) for _, true_label, predicted_label in errors)

    for mistake, count in error_counter.most_common(10):
        true_label, predicted_label = mistake
        indices = [idx for idx, true, pred in errors if true == true_label and pred == predicted_label][:10]

        print(f"True Label: {true_label}, Predicted Label: {predicted_label}, Count: {count}")
        for idx in indices:
            query = decode_one_hot(X_test_encoded[idx])
            print(f"  Query '{query}' at Index {idx}")

# Splits for training and testing
splits = [(0.8, 0.2), (0.5, 0.5), (0.25, 0.75), (0.1, 0.9)]

# Collecting errors for each split
split_errors = {}

# Initializing dictionaries to store accuracy data
train_accuracies = {}
val_accuracies = {}

for train_size, test_size in splits:
    print(f"Training with split {train_size}-{test_size}")

    # Split the dataset
    X_train, X_test, y_train, y_test = train_test_split(X_text_onehot, y_text_onehot, train_size=train_size, test_size=test_size, random_state=42)

    # Build and train the model
    model = build_text2text_multiplication_model()
    history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1)

    # Storing accuracies for plotting
    train_accuracies[f"{train_size}"] = history.history['accuracy']
    val_accuracies[f"{train_size}"] = history.history['val_accuracy']

    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f"Test Accuracy: {accuracy}")

    # Collect misclassification errors
    predictions = model.predict(X_test)
    split_errors[f"{train_size}"] = collect_misclassification_errors(predictions, y_test)
# Out:
# Training with split 0.8-0.2
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_44 (LSTM)              (None, 256)               275456
#
#  repeat_vector_20 (RepeatVe  (None, 5, 256)            0
#  ctor)
#
#  lstm_45 (LSTM)              (None, 5, 256)            525312
#
#  time_distributed_18 (TimeD  (None, 5, 12)             3084
#  istributed)
#
# =================================================================
# Total params: 803852 (3.07 MB)
# Trainable params: 803852 (3.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 113/113 [==============================] - 6s 15ms/step - loss: 1.8089 - accuracy: 0.3548 - val_loss: 1.6123 - val_accuracy: 0.4117
# Epoch 2/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.5493 - accuracy: 0.4271 - val_loss: 1.5449 - val_accuracy: 0.4210
# Epoch 3/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.4939 - accuracy: 0.4327 - val_loss: 1.4937 - val_accuracy: 0.4302
# Epoch 4/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.4490 - accuracy: 0.4445 - val_loss: 1.4476 - val_accuracy: 0.4437
# Epoch 5/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.3984 - accuracy: 0.4606 - val_loss: 1.4186 - val_accuracy: 0.4440
# Epoch 6/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.3511 - accuracy: 0.4772 - val_loss: 1.3497 - val_accuracy: 0.4723
# Epoch 7/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.2844 - accuracy: 0.4991 - val_loss: 1.2483 - val_accuracy: 0.4983
# Epoch 8/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.2114 - accuracy: 0.5204 - val_loss: 1.1805 - val_accuracy: 0.5365
# Epoch 9/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.1363 - accuracy: 0.5458 - val_loss: 1.1353 - val_accuracy: 0.5362
# Epoch 10/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.0956 - accuracy: 0.5587 - val_loss: 1.0987 - val_accuracy: 0.5500
# Epoch 11/50
# 113/113 [==============================] - 1s 7ms/step - loss: 1.0573 - accuracy: 0.5732 - val_loss: 1.0929 - val_accuracy: 0.5548
# 15/15 [==============================] - 0s 10ms/step - loss: 1.3007 - accuracy: 0.5071 - val_loss: 1.4653 - val_accuracy: 0.4400
# Epoch 47/50
# 15/15 [==============================] - 0s 9ms/step - loss: 1.3105 - accuracy: 0.5049 - val_loss: 1.4524 - val_accuracy: 0.4360
# Epoch 48/50
# 15/15 [==============================] - 0s 9ms/step - loss: 1.3046 - accuracy: 0.5102 - val_loss: 1.4867 - val_accuracy: 0.4240
# Epoch 49/50
# 15/15 [==============================] - 0s 10ms/step - loss: 1.3281 - accuracy: 0.5042 - val_loss: 1.4456 - val_accuracy: 0.4340
# Epoch 50/50
# 15/15 [==============================] - 0s 10ms/step - loss: 1.2732 - accuracy: 0.5216 - val_loss: 1.4476 - val_accuracy: 0.4500
# 282/282 [==============================] - 1s 4ms/step - loss: 1.3784 - accuracy: 0.4825
# Test Accuracy: 0.48253333568573
# 282/282 [==============================] - 39s 4ms/step

# %%
# Define a list of colors for the plots
colors = ['tab:blue', 'tab:green', 'tab:orange', 'tab:red']

# Plotting
plt.figure(figsize=(10, 6))
for i, train_size in enumerate(splits):
    split = train_size[0]
    color = colors[i]
    plt.plot(train_accuracies[f"{split}"], label=f"Train {split}", color=color, marker='.')
    plt.plot(val_accuracies[f"{split}"], linestyle='dotted', label=f"Validation {split}", color=color, marker='.')

plt.title("Model Accuracy vs Epochs for Different Training Set Sizes")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# We observe overfitting at an earlier stage, meaning that this model has less generalization power compared to the text-to-text model for basic arithmetics.
#
# The results from the top missclassification mistakes corroborate this, as some mistakes involve 2 wrong digits compared to only 1 in the text-to-text model for basic arithmetics.

# %% [markdown]
# # 2.2 Image-to-text multiplication model

# %%
X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

def build_image_to_text_multiplication_model():
    input_shape = (5, 28, 28, 1)  # Assuming 5 images for each query, modify if needed

    # Adjust max_answer_length for multiplication
    max_answer_length = 5  # Maximum length of multiplication answer
    unique_characters = '0123456789* '  # Adjust as per the multiplication dataset

    # Building the model
    input_layer = Input(shape=input_shape)
    cnn = TimeDistributed(Conv2D(32, kernel_size=(3, 3), activation='relu'))(input_layer)
    cnn = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(cnn)
    cnn = TimeDistributed(Flatten())(cnn)
    lstm = LSTM(128)(cnn)
    repeated_context = RepeatVector(max_answer_length)(lstm)
    lstm_output = LSTM(128, return_sequences=True)(repeated_context)
    output = TimeDistributed(Dense(len(unique_characters), activation='softmax'))(lstm_output)

    model = Model(inputs=input_layer, outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()

    return model

# Prepare and split the data (assuming you've already loaded and prepared X_img and y_text for multiplication)
X_img_reshaped = X_img.reshape((-1, 5, 28, 28, 1)) / 255.0
X_train, X_test, y_train, y_test = train_test_split(X_img_reshaped, y_text_onehot, train_size=0.8, test_size=0.2, random_state=42)

# Build and train the model
image_to_text_multiplication_model = build_image_to_text_multiplication_model()
history = image_to_text_multiplication_model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.1)

# Evaluate the model
loss, accuracy = image_to_text_multiplication_model.evaluate(X_test, y_test)
print(f"Image-to-Text Multiplication Model Test Accuracy: {accuracy}")

# Plotting the learning curves
plt.figure(figsize=(12, 6))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 5, 28, 28, 1)]    0
#
#  time_distributed_9 (TimeDi  (None, 5, 26, 26, 32)     320
#  stributed)
#
#  time_distributed_10 (TimeD  (None, 5, 13, 13, 32)     0
#  istributed)
#
#  time_distributed_11 (TimeD  (None, 5, 5408)           0
#  istributed)
#
#  lstm_16 (LSTM)              (None, 128)               2834944
#
#  repeat_vector_8 (RepeatVec  (None, 5, 128)            0
#  tor)
#
#  lstm_17 (LSTM)              (None, 5, 128)            131584
#
#  time_distributed_12 (TimeD  (None, 5, 12)             1548
#  istributed)
#
# =================================================================
# Total params: 2968396 (11.32 MB)
# Trainable params: 2968396 (11.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 113/113 [==============================] - 12s 23ms/step - loss: 1.9224 - accuracy: 0.3316 - val_loss: 1.8000 - val_accuracy: 0.3602
# Epoch 2/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.7873 - accuracy: 0.3644 - val_loss: 1.7977 - val_accuracy: 0.3498
# Epoch 3/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.7786 - accuracy: 0.3638 - val_loss: 1.7823 - val_accuracy: 0.3575
# Epoch 4/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.7748 - accuracy: 0.3635 - val_loss: 1.7699 - val_accuracy: 0.3575
# Epoch 5/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.7348 - accuracy: 0.3684 - val_loss: 1.7244 - val_accuracy: 0.3647
# Epoch 6/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.7104 - accuracy: 0.3744 - val_loss: 1.7100 - val_accuracy: 0.3665
# Epoch 7/50
# 113/113 [==============================] - 1s 13ms/step - loss: 1.6955 - accuracy: 0.3801 - val_loss: 1.6974 - val_accuracy: 0.3722
# Epoch 8/50
# 113/113 [==============================] - 1s 12ms/step - loss: 1.6712 - accuracy: 0.3875 - val_loss: 1.6680 - val_accuracy: 0.3808
# Epoch 9/50
# 113/113 [==============================] - 1s 12ms/step - loss: 1.6428 - accuracy: 0.3969 - val_loss: 1.6471 - val_accuracy: 0.3832
# Epoch 10/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.6204 - accuracy: 0.4025 - val_loss: 1.6230 - val_accuracy: 0.3920
# Epoch 11/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.6027 - accuracy: 0.4070 - val_loss: 1.6099 - val_accuracy: 0.3995
# Epoch 12/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.5809 - accuracy: 0.4131 - val_loss: 1.5790 - val_accuracy: 0.4065
# Epoch 13/50
# 113/113 [==============================] - 1s 11ms/step - loss: 1.5587 - accuracy: 0.4226 - val_loss: 1.5728 - val_accuracy: 0.4200
# Epoch 14/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.5416 - accuracy: 0.4271 - val_loss: 1.5510 - val_accuracy: 0.4180
# Epoch 15/50
# Epoch 35/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.2293 - accuracy: 0.5334 - val_loss: 1.4190 - val_accuracy: 0.4647
# Epoch 36/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.2152 - accuracy: 0.5395 - val_loss: 1.4320 - val_accuracy: 0.4618
# Epoch 37/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.1947 - accuracy: 0.5495 - val_loss: 1.4352 - val_accuracy: 0.4710
# Epoch 38/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.1802 - accuracy: 0.5558 - val_loss: 1.4457 - val_accuracy: 0.4725
# Epoch 39/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.1604 - accuracy: 0.5651 - val_loss: 1.4580 - val_accuracy: 0.4733
# Epoch 40/50
# 113/113 [==============================] - 1s 13ms/step - loss: 1.1420 - accuracy: 0.5739 - val_loss: 1.4692 - val_accuracy: 0.4712
# Epoch 41/50
# 113/113 [==============================] - 1s 13ms/step - loss: 1.1237 - accuracy: 0.5811 - val_loss: 1.4750 - val_accuracy: 0.4748
# Epoch 42/50
# 113/113 [==============================] - 1s 13ms/step - loss: 1.1053 - accuracy: 0.5873 - val_loss: 1.4711 - val_accuracy: 0.4695
# Epoch 43/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.0804 - accuracy: 0.6008 - val_loss: 1.5019 - val_accuracy: 0.4710
# Epoch 44/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.0589 - accuracy: 0.6097 - val_loss: 1.4986 - val_accuracy: 0.4655
# Epoch 45/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.0385 - accuracy: 0.6197 - val_loss: 1.5158 - val_accuracy: 0.4740
# Epoch 46/50
# 113/113 [==============================] - 1s 10ms/step - loss: 1.0148 - accuracy: 0.6290 - val_loss: 1.5301 - val_accuracy: 0.4787
# Epoch 47/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.9887 - accuracy: 0.6405 - val_loss: 1.5607 - val_accuracy: 0.4760
# Epoch 48/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.9640 - accuracy: 0.6514 - val_loss: 1.5809 - val_accuracy: 0.4750
# Epoch 49/50
# 113/113 [==============================] - 1s 10ms/step - loss: 0.9422 - accuracy: 0.6610 - val_loss: 1.5929 - val_accuracy: 0.4710
# Epoch 50/50
# 113/113 [==============================] - 1s 11ms/step - loss: 0.9183 - accuracy: 0.6723 - val_loss: 1.6232 - val_accuracy: 0.4762
# 63/63 [==============================] - 0s 5ms/step - loss: 1.5727 - accuracy: 0.4850
# Image-to-Text Multiplication Model Test Accuracy: 0.48500001430511475

# %% [markdown]
# # 2.3: Hyperparameter and model architecture tuning to increase model accuracy

# %%
X_text_onehot = encode_labels(X_text)
y_text_onehot = encode_labels(y_text)

def build_image_to_text_multiplication_model():
    input_shape = (5, 28, 28, 1)  # Assuming 5 images for each query, modify if needed

    # Adjust max_answer_length for multiplication
    max_answer_length = 5  # Maximum length of multiplication answer
    unique_characters = '0123456789* '  # Adjust as per the multiplication dataset

    # Building the model
    input_layer = Input(shape=input_shape)

    # CNN for feature extraction from each image, wrapped in TimeDistributed
    cnn = TimeDistributed(Conv2D(32, kernel_size=(3, 3), activation='relu'))(input_layer)
    cnn = TimeDistributed(Conv2D(64, kernel_size=(3, 3), activation='relu'))(cnn)
    cnn = TimeDistributed(MaxPooling2D(pool_size=(2, 2)))(cnn)
    cnn = TimeDistributed(Dropout(0.25))(cnn)
    cnn = TimeDistributed(Flatten())(cnn)
    cnn = TimeDistributed(Dense(128, activation='relu'))(cnn)
    cnn = TimeDistributed(Dropout(0.5))(cnn)

    # RNN (LSTM) for understanding the sequence
    lstm = LSTM(128)(cnn)

    # RepeatVector to repeat context for each time step in the output
    repeated_context = RepeatVector(max_answer_length)(lstm)

    # Another LSTM layer with return_sequences=True for generating the sequence
    lstm_output = LSTM(128, return_sequences=True)(repeated_context)

    # Dense layer to output the textual answer in one-hot format at each time step
    output = TimeDistributed(Dense(len(unique_characters), activation='softmax'))(lstm_output)

    model = Model(inputs=input_layer, outputs=output)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()

    return model

# Prepare and split the data (assuming you've already loaded and prepared X_img and y_text for multiplication)
X_img_reshaped = X_img.reshape((-1, 5, 28, 28, 1)) / 255.0
X_train, X_test, y_train, y_test = train_test_split(X_img_reshaped, y_text_onehot, train_size=0.8, test_size=0.2, random_state=42)

# Build and train the model
image_to_text_multiplication_model = build_image_to_text_multiplication_model()
history = image_to_text_multiplication_model.fit(X_train, y_train, epochs=100, batch_size=64, validation_split=0.1)

# Evaluate the model
loss, accuracy = image_to_text_multiplication_model.evaluate(X_test, y_test)
print(f"Image-to-Text Multiplication Model Test Accuracy: {accuracy}")

# Plotting the learning curves
plt.figure(figsize=(12, 6))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 28, 28, 1)]    0
#
#  time_distributed (TimeDist  (None, 5, 26, 26, 32)     320
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 5, 24, 24, 64)     18496
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 5, 12, 12, 64)     0
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 5, 12, 12, 64)     0
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 5, 9216)           0
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 5, 128)            1179776
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 5, 128)            0
#  stributed)
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  repeat_vector (RepeatVecto  (None, 5, 128)            0
#  r)
#
#  lstm_1 (LSTM)               (None, 5, 128)            131584
#
#  time_distributed_7 (TimeDi  (None, 5, 12)             1548
#  stributed)
#
# =================================================================
# Total params: 1463308 (5.58 MB)
# Trainable params: 1463308 (5.58 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
#